# %% [markdown]
# # Map, Filter, Reduce, Lambda & Recursion

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Lambda Functions</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Saving to a Variable <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Multiple Inputs <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Passing a Lambda into a Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Returning a Lambda from a Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) In-Class Exercise #1 <br>
# 2) <b>Map</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Map <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #2 <br>
# 3) <b>Filter</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Filter <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #3 <br>
# 4) <b>Reduce</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Reduce <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #4 <br>
# 5) <b>Recursion</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Implementing a Base <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Writing a Factorial Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #5 <br>
# 6) <b>Generators & Iterators</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Yield Keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Inifinite Generator <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #6 <br>
# 7) <b>Exercises</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Exercise #1 - Filtering Empty Strings <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Exercise #2 - Sorting with Last Name <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Exercise #3 - Conversion to Farhenheit <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Exercise #4 - Fibonacci Sequence <br>

# %% [markdown]
# ## Lambda Functions <br>
# <p>Lambda functions... or "Anonymous Functions" are referring to inline functions with no name. The keyword lambda denotes the no name function, and executes within a single line. Without saving it to a variable; however, it is not able to be used, unless passed in either as a paramater or within list comprehension.<br>Written as "(keyword lambda) (one or more inputs) (colon) (function to be executed)"</p>

# %% [markdown]
# #### Syntax

# %%
def adder(a, b):
    print("Adding A and B")
    return a + b
    
print(adder(10, 25))
# Out:
# Adding A and B
# 35

# %%
(lambda a,b: a + b)(10, 25)
# Out:
# 35

# %% [markdown]
# #### Saving to a Variable

# %%
adder2 = lambda a, b: a + b

# %%
adder2(10,25)
# Out:
# 35

# %% [markdown]
# #### Multiple Inputs

# %%
(lambda a,b: a + b)(10, 25)
# Out:
# 35

# %% [markdown]
# #### Passing a Lambda into a Function

# %%
from unittest import result


def is_greater_than_25(num):
    # if num > 25:
        # return True
    # else:
        # return False
    return num > 25

def is_past_j(a_str):
    return a_str.lower() > "j"

def custom_filter(arr, filter_f):
    # For example, filter out items that are greater than 25
    result_list = []

    for num in arr:
        if filter_f(num):
            result_list.append(num)

    return result_list

# %%
print(custom_filter([25, 26, 30, 15, 20, 28, 25, 8], is_greater_than_25))
# Out:
# [26, 30, 28]

# %%
print(custom_filter(["Lucus", "Christ", "Joel", "Adam", "Jennifer", "Sarah"], is_past_j))
# Out:
# ['Lucus', 'Joel', 'Jennifer', 'Sarah']

# %%
print(custom_filter([25, 26, 30, 15, 20, 28, 25, 8], lambda num: num > 25))
# Out:
# [26, 30, 28]

# %%
print(custom_filter(["Lucus", "Christ", "Joel", "Adam", "Jennifer", "Sarah"], lambda a_str: a_str.lower() > "j"))
# Out:
# ['Lucus', 'Joel', 'Jennifer', 'Sarah']

# %%
print(custom_filter(["Lucus", "Christ", "Joel", "Adam", "Jennifer", "Sarah"], lambda a_str: a_str.lower() > "c"))
# Out:
# ['Lucus', 'Christ', 'Joel', 'Jennifer', 'Sarah']

# %% [markdown]
# #### Returning a Lambda from a Function

# %% [markdown]
# #### If Statements within Lambdas

# %%
# multiply your item by 3 if the item is odd, multiply by 2 if the item is even

multiply_by_3 = lambda x: x * 3 if x % 2 == 1 else x * 2

# %%
multiply_by_3(3)
# Out:
# 9

# %%
multiply_by_3(4)
# Out:
# 8

# %% [markdown]
# #### In-Class Exercise #1 <br>
# <p>Write an anonymous function that cubes the arguments passed in and assign the anonymous function to a variable 'f'.</p>

# %%
def is_greater_than_25(num):
    # if num > 25:
        # return True
    # else:
        # return False
    return num > 25

def is_past_j(a_str):
    return a_str.lower() > "j"

def custom_filter(arr, filter_f):
    # For example, filter out items that are greater than 25
    result_list = []

    for num in arr:
        if filter_f(num):
            result_list.append(num)

    return result_list

def cubed(num):
    x = num * num * num
    print(x)

# %%
f = lambda x: x ** 3
f(5)
# Out:
# 125

# %% [markdown]
# ## Map <br>
# <p>The map function allows you to iterate over an entire list while running a function on each item of the list. This is why the map function works well with lambda's, because it simplifies things and you write less lines of code.<br>The syntax for a map function is "map(function to be used, list to be used)"<br>However, you must be careful, as the map function returns a map object, not a list. To turn it into a list we use the list() type conversion.</p>

# %% [markdown]
# #### Syntax

# %%
a_list = [1, 5, 10, 4, 3]

def custom_map(a_list, map_f):
    result_list = []

    for num in a_list:
        new_num = map_f(num)
        result_list.append(new_num)

    return result_list

# %%
list(map(lambda x: x * 2, a_list))
# Out:
# [2, 10, 20, 8, 6]

# %% [markdown]
# #### Using Lambda's with Map

# %%
list(map(lambda x: x * 2, a_list))
# Out:
# [2, 10, 20, 8, 6]

# %% [markdown]
# #### In-Class Exercise #2 <br>
# <p>Use the map function to make an entire list of strings uppercase</p>

# %%
list_c = ["Bob", "cat", "doG"]

def new_map(list_c, map_1):
    list_done = []

    for string in list_c:
        capital = map_1(str)
        list_done.append(capital)

    return list_done

# %%
list(map(lambda x: x.upper(), list_c))
# Out:
# ['BOB', 'CAT', 'DOG']

# %% [markdown]
# ## Filter() <br>
# <p>Filter's are similar to the map function, where you're able to pass a function argument and a list argument and filter out something from the list based on the conditions passed. Similar to the map function, it returns a filter object, so you need to type convert it to a list()</p>

# %% [markdown]
# #### Syntax

# %%
a_list = [25, 26, 30, 15, 10, 28, 25, 8]

def custom_filter(a_list, map_f):
    result_list = []

    for num in arr:
        if filter_f(num):
            result_list.append(num)

    return result_list

# %%
list(custom_filter([25, 26, 30, 15, 10, 28, 25, 8], lambda num: num > 25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb Cell 40 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> list(custom_filter([25, 26, 30, 15, 10, 28, 25, 8], lambda num: num > 25))
#
# /Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb Cell 40 in custom_filter(a_list, map_f)
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X54sZmlsZQ%3D%3D?line=2'>3</a> def custom_filter(a_list, map_f):
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X54sZmlsZQ%3D%3D?line=3'>4</a>     result_list = []
# ----> <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X54sZmlsZQ%3D%3D?line=5'>6</a>     for num in arr:
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X54sZmlsZQ%3D%3D?line=6'>7</a>         if filter_f(num):
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X54sZmlsZQ%3D%3D?line=7'>8</a>             result_list.append(num)
#
# NameError: name 'arr' is not defined

# %%
list(filter(lambda num: num > 25, [25, 26, 30, 15, 10, 28, 25, 8]))
# Out:
# [26, 30, 28]

# %%
# Class members -remove all of the people who come after Christopher
class_members = ['Lucas', 'Christopher', 'Joel', 'Abby', 'Anna', 'Zeke']
list(filter(lambda name: name <= 'Christopher', class_members))
# Out:
# ['Christopher', 'Abby', 'Anna']

# %%
# Take in a list of numbers, filter out all numbers smaller than the last number
numbers = [10,25,13,15,27,14]
list(filter(lambda x: x >= numbers[-1], numbers))
# Out:
# [25, 15, 27, 14]

# %% [markdown]
# #### Using Lambda's with Filter()

# %% [markdown]
# #### In-Class Exercise #3 <br>
# <p>Filter out all the numbers that are below the mean of the list.<br><b>Hint: Import the 'statistics' module</b></p>

# %%
def Average(list_a):
    return sum(list_a) / len(list_a)

list_a = [25, 26, 30, 15, 10, 28, 25, 8]
average = Average(list_a)

print("Average of the list =", round(average, 2))
# Out:
# Average of the list = 20.88

# %%
list(filter(lambda x: x > 25, [25, 26, 30, 15, 10, 28, 25, 8]))
# Out:
# [26, 30, 28]

# %%
from statistics import mean

numbers = [25, 26, 30, 15, 10, 28, 25, 8, 0, 0]

list(filter(lambda x: x > sum(x) / len(x), numbers))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb Cell 49 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> from statistics import mean
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X66sZmlsZQ%3D%3D?line=2'>3</a> numbers = [25, 26, 30, 15, 10, 28, 25, 8, 0, 0]
# ----> <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X66sZmlsZQ%3D%3D?line=4'>5</a> list(filter(lambda x: x > sum(x) / len(x), numbers))
#
# /Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb Cell 49 in <lambda>(x)
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> from statistics import mean
#       <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X66sZmlsZQ%3D%3D?line=2'>3</a> numbers = [25, 26, 30, 15, 10, 28, 25, 8, 0, 0]
# ----> <a href='vscode-notebook-cell:/Users/linzhenxin/Downloads/Week-3/Day-1/Homework/Advanced-Python-BuiltInFunctions-Map-Filter-Reduce-Recursion-Updated-Lecture-Rangers59.ipynb#X66sZmlsZQ%3D%3D?line=4'>5</a> list(filter(lambda x: x > sum(x) / len(x), numbers))
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# ## Reduce() <br>
# <p>Be very careful when using this function, as of Python 3 it's been moved to the 'functools' library and no longer is a built-in function.<br>The creator of Python himself, says to just use a for loop instead.</p>

# %% [markdown]
# #### Syntax

# %%
from functools import reduce

# a_list = [10 , 25, 32, 15]
a_list = [10 , 25, 32, 15]

def sum_numbers(num1, num2):
    print(num1, num2)
    return num1 + num2

reduce(sum_numbers, a_list)
# Out:
# 10 2
# 12

# %%
my_sum = 0

for num in a_list:
    my_sum += num

print(my_sum)
# Out:
# 12

# %% [markdown]
# #### Using Lambda's with Reduce()

# %%
reduce(lambda x, y: x + y, a_list)
# Out:
# 12

# %% [markdown]
# #### In-Class Exercise #4 <br>
# <p>Use the reduce function to multiply the numbers in the list below together with a lambda function.</p>

# %%
reduce(lambda x, y: x * y, a_list)
# Out:
# 20

# %% [markdown]
# ## Recursion <br>
# <p>Recursion means that a function is calling itself, so it contanstly executes until a base case is reached. It will then push the returning values back up the chain until the function is complete. A prime example of recursion is computing factorials... such that 5! (factorial) is 5*4*3*2*1 which equals 120.</p>

# %% [markdown]
# #### Implementing a Base Case

# %%
# Factorial 4, 4!
# 4 * 3 * 2 * 1
fact = 4
result = 1
for i in range(1, fact + 1):
    result *= i

print(result)
# Out:
# 24

# %% [markdown]
# #### Writing a Factorial Function

# %%
def factorial(num):
    if num ==1:
        return 1
    else:
        return num * factorial(num - 1)

# %%
factorial(4)
# Out:
# 24

# %% [markdown]
# #### In-Class Exercise #5 <br>
# <p>Write a recursive function that subtracts all numbers to the argument given.</p>

# %%
def subtract_numbers(num):
    if num == 1:
        print(f'subtract_numbers(1) = 1')
        return 1
    else:
        print(f'subtract_numbers({num}) = {num} - subtract_numbers({num})')
        return num - subtract_numbers(num - 1)

subtract_numbers(5) # Result: 3
# Out:
# subtract_numbers(5) = 5 - subtract_numbers(5)
# subtract_numbers(4) = 4 - subtract_numbers(4)
# subtract_numbers(3) = 3 - subtract_numbers(3)
# subtract_numbers(2) = 2 - subtract_numbers(2)
# subtract_numbers(1) = 1
# 3

# %%
# 5 - (4 - (3 - (2 - 1)))

# %% [markdown]
# ## Generators <br>
# <p>Generators are a type of iterable, like lists or tuples. They do not allow indexing, but they can still be iterated through with for loops. They are created using functions and the yield statement.</p>

# %% [markdown]
# #### Yield Keyword <br>
# <p>The yield keyword denotes a generator, it doesn't return so it won't leave the function and reset all variables in the function scope, instead it yields the number back to the caller.</p>

# %% [markdown]
# #### Infinite Generator

# %%
# bad, never create infinite loops

# %% [markdown]
# #### In-Class Exercise #6 <br>
# <p>Create a generator that takes a number argument and yields that number squared, then prints each number squared until zero is reached.</p>

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Exercise #1 <br>
# <p>Filter out all of the empty strings from the list below</p>
#
# `Output: ['Argentina', 'San Diego', 'Boston', 'New York']`

# %%
from re import X


# places = [" ","Argentina", " ", "San Diego","","  ","","Boston","New York"]

# def remove_blank(places):
#     results = []

#     for place in places:
#         if not place.isspace() and len(place) > 0:
#             results.append(place)
#     return results

# remove_blank(places)

# a_list = [25, 26, 30, 15, 10, 28, 25, 8]

# def custom_filter(a_list, map_f):
#     result_list = []

#     for num in arr:
#         if filter_f(num):
#             result_list.append(num)

#     return result_list

# list(custom_filter([25, 26, 30, 15, 10, 28, 25, 8], lambda num: num > 25))

list(filter(lambda place: not place.isspace() and len(place) > 0, [" ","Argentina", " ", "San Diego","","  ","","Boston","New York"]))
# Out:
# ['Argentina', 'San Diego', 'Boston', 'New York']

# %% [markdown]
# ### Exercise #2 <br>
# <p>Write an anonymous function that sorts this list by the last name...<br><b>Hint: Use the ".sort()" method and access the key"</b></p>
#
# `Output: ['Victor aNisimov', 'Gary A.J. Bernstein', 'Joel Carter', 'Andrew P. Garfield', 'David hassELHOFF']`

# %%
authors = ["Joel Carter", "Victor aNisimov", "Andrew P. Garfield" ,"David hassELHOFF", "Gary A.J. Bernstein"]

authors.sort(key = lambda x: (x.split()[-1][0]).lower())

print(authors)
# Out:
# ['Victor aNisimov', 'Gary A.J. Bernstein', 'Joel Carter', 'Andrew P. Garfield', 'David hassELHOFF']

# %% [markdown]
# ### Exercise #3 <br>
# <p>Convert the list below from Celsius to Farhenheit, using the map function with a lambda...</p>
#
# `Output: [('Nashua', 89.6), ('Boston', 53.6), ('Los Angelos', 111.2), ('Miami', 84.2)]
# `

# %%
# F = (9/5)*C + 32
places = [('Nashua', 32),("Boston", 12),("Los Angelos", 44),("Miami", 29)]

Convert = list(map(lambda x: x[1] * (9/5) + 32 , places))

print(Convert)


# Generic For Loop Practice

# place = ["Bob", "Cat"]
# test_list = []
# def testing():
#     for x in place:
#         test_list.append(x)
#     return test_list

# testing()
# Out:
# [89.6, 53.6, 111.2, 84.2]

# %% [markdown]
# ### Exercise #4 <br>
# <p>Write a recursion function to perform the fibonacci sequence up to the number passed in.</p>
#
# `Output for fib(5) =>
# Iteration 0: 1
# Iteration 1: 1
# Iteration 2: 2
# Iteration 3: 3
# Iteration 4: 5
# Iteration 5: 8`

# %%
def seq(x):
    if x == 1 or x == 2:
        return 1 
    else:
        return(seq(x - 1) + seq(x - 2))
        
seq(10)
# Out:
# 55
